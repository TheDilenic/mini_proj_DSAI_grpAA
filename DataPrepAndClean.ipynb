# %% [markdown]
# ## Data Prep

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
sb.set()

# %% [markdown]
# #### Read data from different sheets

# %%
Main_data = pd.read_excel('climate_change_dataset.xlsx')
Main_data.head()
# Out:
#   Country code Country name     Series code  \
# 0          ABW        Aruba  AG.LND.EL5M.ZS
# 1          ADO      Andorra  AG.LND.EL5M.ZS
# 2          AFG  Afghanistan  AG.LND.EL5M.ZS
# 3          AGO       Angola  AG.LND.EL5M.ZS
# 4          ALB      Albania  AG.LND.EL5M.ZS
#
#                            Series name SCALE Decimals      1990 1991 1992  \
# 0  Land area below 5m (% of land area)     0        1  29.57481   ..   ..
# 1  Land area below 5m (% of land area)     0        1         0   ..   ..
# 2  Land area below 5m (% of land area)     0        1         0   ..   ..
# 3  Land area below 5m (% of land area)     0        1  0.208235   ..   ..
# 4  Land area below 5m (% of land area)     0        1  4.967875   ..   ..
#
#   1993  ... 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
# 0   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 1   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 2   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 3   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 4   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Convert "Year" to long format

# %%
Main_data_long = Main_data.melt(
    id_vars=["Country code", "Country name", "Series code", "Series name", "SCALE", "Decimals"],   # columns to keep
    var_name="Year",       # new column for former year column names
    value_name="Value"     # new column for values
)

# Convert Year to numeric 
Main_data_long["Year"] = pd.to_numeric(Main_data_long["Year"], errors="coerce")

Main_data_long.head()
# Out:
#   Country code Country name     Series code  \
# 0          ABW        Aruba  AG.LND.EL5M.ZS
# 1          ADO      Andorra  AG.LND.EL5M.ZS
# 2          AFG  Afghanistan  AG.LND.EL5M.ZS
# 3          AGO       Angola  AG.LND.EL5M.ZS
# 4          ALB      Albania  AG.LND.EL5M.ZS
#
#                            Series name SCALE Decimals  Year     Value
# 0  Land area below 5m (% of land area)     0        1  1990  29.57481
# 1  Land area below 5m (% of land area)     0        1  1990         0
# 2  Land area below 5m (% of land area)     0        1  1990         0
# 3  Land area below 5m (% of land area)     0        1  1990  0.208235
# 4  Land area below 5m (% of land area)     0        1  1990  4.967875

# %% [markdown]
# #### Convert "Series name" to wide format

# %%
# Convert Value to numeric 
Main_data_long['Value'] = pd.to_numeric(Main_data_long['Value'], errors='coerce')

# Pivot data to wide
df_wide = Main_data_long.pivot_table(
    index=['Country code', 'Country name', 'Year'],
    columns='Series name',
    values='Value',
    aggfunc='first'   # take the first one if there are duplicates
).reset_index()

# Remove the column name hierarchy
df_wide.columns.name = None

df_wide.head()
# Out:
#   Country code Country name  Year  \
# 0          ABW        Aruba  1990
# 1          ABW        Aruba  1991
# 2          ABW        Aruba  1992
# 3          ABW        Aruba  1993
# 4          ABW        Aruba  1994
#
#    Access to electricity (% of total population)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Access to improved sanitation (% of total pop.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Access to improved water source (% of total pop.)  \
# 0                                              100.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural land under irrigation (% of total ag. land)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annual freshwater withdrawals (% of internal resources)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Average annual precipitation (1961-1990, mm)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    CO2 emissions per capita (metric tons)  ...  \
# 0                               29.620641  ...
# 1                               29.838835  ...
# 2                               25.239288  ...
# 3                               24.405233  ...
# 4                               22.977867  ...
#
#    Population below 5m (% of total)  Population growth (annual %)  \
# 0                          29.57482                      1.820254
# 1                               NaN                      3.936181
# 2                               NaN                      5.484041
# 3                               NaN                      6.088818
# 4                               NaN                      5.611677
#
#    Population in urban agglomerations >1million (%)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Population living below $1.25 a day (% of total)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Primary completion rate, total (% of relevant age group)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Public sector mgmt & institutions avg. (1-6 scale; 6=best)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Ratio of girls to boys in primary & secondary school (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Under-five mortality rate (per 1,000)  Urban population  \
# 0                                    NaN         31259.941
# 1                                    NaN         32321.000
# 2                                    NaN         33938.142
# 3                                    NaN         35851.062
# 4                                    NaN         37690.142
#
#    Urban population growth (annual %)
# 0                            1.780501
# 1                            3.337974
# 2                            4.882234
# 3                            5.483368
# 4                            5.002538
#
# [5 rows x 51 columns]

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5085 entries, 0 to 5084
# Data columns (total 51 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Country code                                                      5085 non-null   object
#  1   Country name                                                      5085 non-null   object
#  2   Year                                                              5085 non-null   int64
#  3   Access to electricity (% of total population)                     99 non-null     float64
#  4   Access to improved sanitation (% of total pop.)                   968 non-null    float64
#  5   Access to improved water source (% of total pop.)                 988 non-null    float64
#  6   Agricultural land under irrigation (% of total ag. land)          442 non-null    float64
#  7   Annual freshwater withdrawals (% of internal resources)           281 non-null    float64
#  8   Average annual precipitation (1961-1990, mm)                      200 non-null    float64
#  9   CO2 emissions per capita (metric tons)                            3980 non-null   float64
#  10  CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)          3569 non-null   float64
#  11  CO2 emissions, total (KtCO2)                                      3983 non-null   float64
#  12  Cereal yield (kg per hectare)                                     3749 non-null   float64
#  13  Child malnutrition, underweight (% of under age 5)                524 non-null    float64
#  14  Disaster risk reduction progress score (1-5 scale; 5=best)        84 non-null     float64
#  15  Droughts, floods, extreme temps (% pop. avg. 1990-2009)           168 non-null    float64
#  16  Ease of doing business (ranking 1-183; 1=best)                    546 non-null    float64
#  17  Energy use per capita (kilograms of oil equivalent)               3170 non-null   float64
#  18  Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $)     3044 non-null   float64
#  19  Foreign direct investment, net inflows (% of GDP)                 4015 non-null   float64
#  20  GDP ($)                                                           4347 non-null   float64
#  21  GHG net emissions/removals by LUCF (MtCO2e)                       943 non-null    float64
#  22  GNI per capita (Atlas $)                                          4113 non-null   float64
#  23  Hosted Clean Development Mechanism (CDM) projects                 92 non-null     float64
#  24  Hosted Joint Implementation (JI) projects                         17 non-null     float64
#  25  Invest. in energy w/ private participation ($)                    855 non-null    float64
#  26  Invest. in telecoms w/ private participation ($)                  1925 non-null   float64
#  27  Invest. in transport w/ private participation ($)                 546 non-null    float64
#  28  Invest. in water/sanit. w/ private participation ($)              324 non-null    float64
#  29  Issued Certified Emission Reductions (CERs) from CDM (thousands)  75 non-null     float64
#  30  Issued Emission Reduction Units (ERUs) from JI (thousands)        8 non-null      float64
#  31  Land area below 5m (% of land area)                               454 non-null    float64
#  32  Malaria incidence rate (per 100,000 people)                       110 non-null    float64
#  33  Methane (CH4) emissions, total (KtCO2e)                           600 non-null    float64
#  34  Nationally terrestrial protected areas (% of total land area)     4400 non-null   float64
#  35  Nitrous oxide (N2O) emissions, total (KtCO2e)                     600 non-null    float64
#  36  Nurses and midwives (per 1,000 people)                            376 non-null    float64
#  37  Other GHG emissions, total (KtCO2e)                               584 non-null    float64
#  38  Paved roads (% of total roads)                                    2037 non-null   float64
#  39  Physicians (per 1,000 people)                                     1653 non-null   float64
#  40  Population                                                        4874 non-null   float64
#  41  Population below 5m (% of total)                                  454 non-null    float64
#  42  Population growth (annual %)                                      4848 non-null   float64
#  43  Population in urban agglomerations >1million (%)                  2544 non-null   float64
#  44  Population living below $1.25 a day (% of total)                  568 non-null    float64
#  45  Primary completion rate, total (% of relevant age group)          2334 non-null   float64
#  46  Public sector mgmt & institutions avg. (1-6 scale; 6=best)        458 non-null    float64
#  47  Ratio of girls to boys in primary & secondary school (%)          2673 non-null   float64
#  48  Under-five mortality rate (per 1,000)                             4410 non-null   float64
#  49  Urban population                                                  4659 non-null   float64
#  50  Urban population growth (annual %)                                4636 non-null   float64
# dtypes: float64(48), int64(1), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Find the country with least missing data

# %%
# Find the percentage of missing data per country
missing_data_country = (
    df_wide.groupby("Country name", group_keys=False)
    .apply(lambda x: x.drop(columns=["Country name"], errors="ignore")
                     .isna().mean().mean() * 100)
)

# Sort by least missing data
least_missing = missing_data_country.sort_values(ascending=True)

# Show top 10
print(least_missing.head(10))
# Out:
# Country name
# Mexico       47.909091
# Indonesia    49.272727
# Poland       49.363636
# Malaysia     50.272727
# Colombia     50.545455
# Turkey       50.818182
# India        50.818182
# Chile        50.818182
# Hungary      50.909091
# Argentina    50.909091
# dtype: float64
# C:\Users\jason\AppData\Local\Temp\ipykernel_26996\2989771401.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.drop(columns=["Country name"], errors="ignore")

# %%
# Define the top 10 countries (least missing data)
top10_countries = [
    "Mexico", "Indonesia", "Poland", "Malaysia", "Colombia",
    "Turkey", "India", "Chile", "Romania", "Argentina"
]

# Filter only those countries
df_filtered = df_wide[df_wide["Country name"].isin(top10_countries)]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Sanity checks

# %%
print("Rows, Cols:", df_filtered.shape)
print("Duplicate rows:", df_filtered.duplicated().sum())
print("\nDtypes:")
df_filtered.dtypes
# Out:
# Rows, Cols: (220, 51)
# Duplicate rows: 0
#
# Dtypes:
# Country code                                                         object
# Country name                                                         object
# Year                                                                  int64
# Access to electricity (% of total population)                       float64
# Access to improved sanitation (% of total pop.)                     float64
# Access to improved water source (% of total pop.)                   float64
# Agricultural land under irrigation (% of total ag. land)            float64
# Annual freshwater withdrawals (% of internal resources)             float64
# Average annual precipitation (1961-1990, mm)                        float64
# CO2 emissions per capita (metric tons)                              float64
# CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)            float64
# CO2 emissions, total (KtCO2)                                        float64
# Cereal yield (kg per hectare)                                       float64
# Child malnutrition, underweight (% of under age 5)                  float64
# Disaster risk reduction progress score (1-5 scale; 5=best)          float64
# Droughts, floods, extreme temps (% pop. avg. 1990-2009)             float64
# Ease of doing business (ranking 1-183; 1=best)                      float64
# Energy use per capita (kilograms of oil equivalent)                 float64
# Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $)       float64
# Foreign direct investment, net inflows (% of GDP)                   float64
# GDP ($)                                                             float64
# GHG net emissions/removals by LUCF (MtCO2e)                         float64
# GNI per capita (Atlas $)                                            float64
# Hosted Clean Development Mechanism (CDM) projects                   float64
# Hosted Joint Implementation (JI) projects                           float64
# Invest. in energy w/ private participation ($)                      float64
# Invest. in telecoms w/ private participation ($)                    float64
# Invest. in transport w/ private participation ($)                   float64
# Invest. in water/sanit. w/ private participation ($)                float64
# Issued Certified Emission Reductions (CERs) from CDM (thousands)    float64
# Issued Emission Reduction Units (ERUs) from JI (thousands)          float64
# Land area below 5m (% of land area)                                 float64
# Malaria incidence rate (per 100,000 people)                         float64
# Methane (CH4) emissions, total (KtCO2e)                             float64
# Nationally terrestrial protected areas (% of total land area)       float64
# Nitrous oxide (N2O) emissions, total (KtCO2e)                       float64
# Nurses and midwives (per 1,000 people)                              float64
# Other GHG emissions, total (KtCO2e)                                 float64
# Paved roads (% of total roads)                                      float64
# Physicians (per 1,000 people)                                       float64
# Population                                                          float64
# Population below 5m (% of total)                                    float64
# Population growth (annual %)                                        float64
# Population in urban agglomerations >1million (%)                    float64
# Population living below $1.25 a day (% of total)                    float64
# Primary completion rate, total (% of relevant age group)            float64
# Public sector mgmt & institutions avg. (1-6 scale; 6=best)          float64
# Ratio of girls to boys in primary & secondary school (%)            float64
# Under-five mortality rate (per 1,000)                               float64
# Urban population                                                    float64
# Urban population growth (annual %)                                  float64
# dtype: object

# %% [markdown]
# #### Replace missing value

# %%
missing_tokens = {"..", "NA", "N/A", "na", "n/a", "", "—", "-"}

df_filtered = df_filtered.copy()

for c in df_filtered.columns:
    if df_filtered[c].dtype == "object":
        df_filtered.loc[:, c] = df_filtered[c].replace(list(missing_tokens), np.nan)

# %% [markdown]
# #### Percentage of missing data in each column

# %%
id_cols = ["Country code", "Country name"] # Identify ID columns (these will not be converted to numeric)
if "Year" in df_filtered.columns:
    df_filtered["Year"] = pd.to_numeric(df_filtered["Year"], errors="coerce").astype("Int64")

metric_cols = [c for c in df_filtered.columns if c not in id_cols + ["Year"]]
for c in metric_cols:
    df_filtered[c] = pd.to_numeric(df_filtered[c], errors="coerce")

# %%
missing_by_col = df_filtered[metric_cols].isna().mean().sort_values(ascending=False) * 100
missing_summary = (missing_by_col.round(2)
                   .rename("Missing %")
                   .reset_index()
                   .rename(columns={"index": "Column"}))
missing_summary.head(20)
# Out:
#                                                Column  Missing %
# 0   Issued Certified Emission Reductions (CERs) fr...     100.00
# 1   Issued Emission Reduction Units (ERUs) from JI...      99.55
# 2           Hosted Joint Implementation (JI) projects      99.09
# 3       Access to electricity (% of total population)      97.27
# 4   Hosted Clean Development Mechanism (CDM) projects      96.82
# 5         Malaria incidence rate (per 100,000 people)      96.82
# 6   Public sector mgmt & institutions avg. (1-6 sc...      96.36
# 7   Disaster risk reduction progress score (1-5 sc...      95.91
# 8   Droughts, floods, extreme temps (% pop. avg. 1...      95.45
# 9        Average annual precipitation (1961-1990, mm)      95.45
# 10             Nurses and midwives (per 1,000 people)      91.82
# 11                Land area below 5m (% of land area)      90.91
# 12  Annual freshwater withdrawals (% of internal r...      90.91
# 13                   Population below 5m (% of total)      90.91
# 14     Ease of doing business (ranking 1-183; 1=best)      86.36
# 15                Other GHG emissions, total (KtCO2e)      81.82
# 16            Methane (CH4) emissions, total (KtCO2e)      81.82
# 17      Nitrous oxide (N2O) emissions, total (KtCO2e)      81.82
# 18  Agricultural land under irrigation (% of total...      81.36
# 19  Access to improved water source (% of total pop.)      79.55

# %% [markdown]
# #### Drop column with missing value>0.80

# %%
drop_threshold = 0.80  # drop columns with >=80% missing
cols_to_drop = missing_by_col[missing_by_col >= drop_threshold*100].index.tolist()
df_reduced = df_filtered.drop(columns=cols_to_drop)

print("Dropped columns (>=80% missing):", len(cols_to_drop))
cols_to_drop[:]  # preview
# Out:
# Dropped columns (>=80% missing): 19
# ['Issued Certified Emission Reductions (CERs) from CDM (thousands)',
#  'Issued Emission Reduction Units (ERUs) from JI (thousands)',
#  'Hosted Joint Implementation (JI) projects',
#  'Access to electricity (% of total population)',
#  'Hosted Clean Development Mechanism (CDM) projects',
#  'Malaria incidence rate (per 100,000 people)',
#  'Public sector mgmt & institutions avg. (1-6 scale; 6=best)',
#  'Disaster risk reduction progress score (1-5 scale; 5=best)',
#  'Droughts, floods, extreme temps (% pop. avg. 1990-2009)',
#  'Average annual precipitation (1961-1990, mm)',
#  'Nurses and midwives (per 1,000 people)',
#  'Land area below 5m (% of land area)',
#  'Annual freshwater withdrawals (% of internal resources)',
#  'Population below 5m (% of total)',
#  'Ease of doing business (ranking 1-183; 1=best)',
#  'Other GHG emissions, total (KtCO2e)',
#  'Methane (CH4) emissions, total (KtCO2e)',
#  'Nitrous oxide (N2O) emissions, total (KtCO2e)',
#  'Agricultural land under irrigation (% of total ag. land)']

# %%
metrics_kept = [c for c in df_reduced.columns if c not in id_cols + ["Year"]]
mask_all_nan = df_reduced[metrics_kept].isna().all(axis=1)
print("Rows removed (all metrics NaN):", int(mask_all_nan.sum()))
df_reduced = df_reduced[~mask_all_nan]
df_reduced.shape
# Out:
# Rows removed (all metrics NaN): 10
# (210, 32)

# %% [markdown]
# #### Impute missing value

# %%
def impute_group(g):
    g = g.sort_values("Year")
    g[metrics_kept] = g[metrics_kept].interpolate(method="linear", limit_direction="both")
    g[metrics_kept] = g[metrics_kept].ffill().bfill()
    return g

df_imputed = df_reduced.groupby("Country name", group_keys=False).apply(impute_group)
df_imputed.shape
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_26996\94145776.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_imputed = df_reduced.groupby("Country name", group_keys=False).apply(impute_group)
# (210, 32)

# %% [markdown]
# #### Keep the data in within the logical limit

# %%
percent_like = [c for c in metrics_kept if "%" in c]
for c in percent_like:
    df_imputed[c] = df_imputed[c].clip(lower=0, upper=100)
percent_like[:10]  # preview clipped columns
# Out:
# ['Access to improved sanitation (% of total pop.)',
#  'Access to improved water source (% of total pop.)',
#  'Child malnutrition, underweight (% of under age 5)',
#  'Foreign direct investment, net inflows (% of GDP)',
#  'Nationally terrestrial protected areas (% of total land area)',
#  'Paved roads (% of total roads)',
#  'Population growth (annual %)',
#  'Population in urban agglomerations >1million (%)',
#  'Population living below $1.25 a day (% of total)',
#  'Primary completion rate, total (% of relevant age group)']

# %%
df_imputed
# Out:
#      Country code Country name  Year  \
# 131           ARG    Argentina  1990
# 132           ARG    Argentina  1991
# 133           ARG    Argentina  1992
# 134           ARG    Argentina  1993
# 135           ARG    Argentina  1994
# ...           ...          ...   ...
# 4619          TUR       Turkey  2006
# 4620          TUR       Turkey  2007
# 4621          TUR       Turkey  2008
# 4622          TUR       Turkey  2009
# 4623          TUR       Turkey  2010
#
#       Access to improved sanitation (% of total pop.)  \
# 131                                         90.000000
# 132                                         90.200000
# 133                                         90.400000
# 134                                         90.600000
# 135                                         90.800000
# ...                                               ...
# 4619                                        89.333333
# 4620                                        89.666667
# 4621                                        90.000000
# 4622                                        90.000000
# 4623                                        90.000000
#
#       Access to improved water source (% of total pop.)  \
# 131                                           94.000000
# 132                                           94.200000
# 133                                           94.400000
# 134                                           94.600000
# 135                                           94.800000
# ...                                                 ...
# 4619                                          97.666667
# 4620                                          98.333333
# 4621                                          99.000000
# 4622                                          99.000000
# 4623                                          99.000000
#
#       CO2 emissions per capita (metric tons)  \
# 131                                 3.449913
# 132                                 3.536073
# 133                                 3.620969
# 134                                 3.490348
# 135                                 3.583651
# ...                                      ...
# 4619                                3.787393
# 4620                                4.066967
# 4621                                4.004017
# 4622                                4.004017
# 4623                                4.004017
#
#       CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)  \
# 131                                          462.560560
# 132                                          426.614517
# 133                                          395.521880
# 134                                          364.733889
# 135                                          358.397431
# ...                                                 ...
# 4619                                         313.221530
# 4620                                         325.664011
# 4621                                         322.761413
# 4622                                         322.761413
# 4623                                         322.761413
#
#       CO2 emissions, total (KtCO2)  Cereal yield (kg per hectare)  \
# 131                     112613.570                         2232.2
# 132                     117021.304                         2666.1
# 133                     121447.373                         3057.3
# 134                     118609.115                         2846.5
# 135                     123350.546                         2815.9
# ...                            ...                            ...
# 4619                    261570.777                         2658.6
# 4620                    284658.209                         2381.4
# 4621                    283979.814                         2487.4
# 4622                    283979.814                         2807.7
# 4623                    283979.814                         2807.7
#
#       Child malnutrition, underweight (% of under age 5)  ...  \
# 131                                                 1.7   ...
# 132                                                 1.7   ...
# 133                                                 1.7   ...
# 134                                                 1.7   ...
# 135                                                 1.7   ...
# ...                                                 ...   ...
# 4619                                                3.5   ...
# 4620                                                3.5   ...
# 4621                                                3.5   ...
# 4622                                                3.5   ...
# 4623                                                3.5   ...
#
#       Physicians (per 1,000 people)  Population  Population growth (annual %)  \
# 131                        2.680000  32642442.0                      1.404532
# 132                        2.682000  33093579.0                      1.372593
# 133                        2.684000  33540023.0                      1.340017
# 134                        2.682667  33982035.0                      1.309256
# 135                        2.681333  34420352.0                      1.281601
# ...                             ...         ...                           ...
# 4619                       1.560000  69063538.0                      1.341575
# 4620                       1.505500  69992754.0                      1.336480
# 4621                       1.451000  70923730.0                      1.321335
# 4622                       1.640000  71846212.0                      1.292282
# 4623                       1.640000  72752325.0                      1.253297
#
#       Population in urban agglomerations >1million (%)  \
# 131                                          39.204392
# 132                                          39.119646
# 133                                          39.042135
# 134                                          38.975668
# 135                                          38.920819
# ...                                                ...
# 4619                                         28.690982
# 4620                                         28.849141
# 4621                                         28.975006
# 4622                                         29.075349
# 4623                                         29.155890
#
#       Population living below $1.25 a day (% of total)  \
# 131                                               0.13
# 132                                               0.13
# 133                                               0.13
# 134                                               0.49
# 135                                               0.85
# ...                                                ...
# 4619                                              2.72
# 4620                                              2.72
# 4621                                              2.72
# 4622                                              2.72
# 4623                                              2.72
#
#       Primary completion rate, total (% of relevant age group)  \
# 131                                           100.00000
# 132                                           100.00000
# 133                                           100.00000
# 134                                           100.00000
# 135                                           100.00000
# ...                                                 ...
# 4619                                           91.67677
# 4620                                           91.05292
# 4621                                           93.42516
# 4622                                           93.42516
# 4623                                           93.42516
#
#       Ratio of girls to boys in primary & secondary school (%)  \
# 131                                             100.000
# 132                                             100.000
# 133                                             100.000
# 134                                             100.000
# 135                                             100.000
# ...                                                 ...
# 4619                                             90.077
# 4620                                             90.963
# 4621                                             92.875
# 4622                                             92.875
# 4623                                             92.875
#
#       Under-five mortality rate (per 1,000)  Urban population  \
# 131                                    26.9      2.839892e+07
# 132                                    25.8      2.890393e+07
# 133                                    24.9      2.940789e+07
# 134                                    24.2      2.991099e+07
# 135                                    23.4      3.041382e+07
# ...                                     ...               ...
# 4619                                   25.1      4.679745e+07
# 4620                                   22.8      4.774906e+07
# 4621                                   21.0      4.871042e+07
# 4622                                   19.1      4.967447e+07
# 4623                                   17.6      5.063562e+07
#
#       Urban population growth (annual %)
# 131                             1.865363
# 132                             1.762636
# 133                             1.728544
# 134                             1.696280
# 135                             1.667133
# ...                                  ...
# 4619                            2.022757
# 4620                            2.013053
# 4621                            1.993361
# 4622                            1.959821
# 4623                            1.916411
#
# [210 rows x 32 columns]

# %%
df_imputed = df_imputed.reset_index(drop=True)
df_imputed.index = df_imputed.index + 1

# %%
df_imputed
# Out:
#     Country code Country name  Year  \
# 1            ARG    Argentina  1990
# 2            ARG    Argentina  1991
# 3            ARG    Argentina  1992
# 4            ARG    Argentina  1993
# 5            ARG    Argentina  1994
# ..           ...          ...   ...
# 206          TUR       Turkey  2006
# 207          TUR       Turkey  2007
# 208          TUR       Turkey  2008
# 209          TUR       Turkey  2009
# 210          TUR       Turkey  2010
#
#      Access to improved sanitation (% of total pop.)  \
# 1                                          90.000000
# 2                                          90.200000
# 3                                          90.400000
# 4                                          90.600000
# 5                                          90.800000
# ..                                               ...
# 206                                        89.333333
# 207                                        89.666667
# 208                                        90.000000
# 209                                        90.000000
# 210                                        90.000000
#
#      Access to improved water source (% of total pop.)  \
# 1                                            94.000000
# 2                                            94.200000
# 3                                            94.400000
# 4                                            94.600000
# 5                                            94.800000
# ..                                                 ...
# 206                                          97.666667
# 207                                          98.333333
# 208                                          99.000000
# 209                                          99.000000
# 210                                          99.000000
#
#      CO2 emissions per capita (metric tons)  \
# 1                                  3.449913
# 2                                  3.536073
# 3                                  3.620969
# 4                                  3.490348
# 5                                  3.583651
# ..                                      ...
# 206                                3.787393
# 207                                4.066967
# 208                                4.004017
# 209                                4.004017
# 210                                4.004017
#
#      CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)  \
# 1                                           462.560560
# 2                                           426.614517
# 3                                           395.521880
# 4                                           364.733889
# 5                                           358.397431
# ..                                                 ...
# 206                                         313.221530
# 207                                         325.664011
# 208                                         322.761413
# 209                                         322.761413
# 210                                         322.761413
#
#      CO2 emissions, total (KtCO2)  Cereal yield (kg per hectare)  \
# 1                      112613.570                         2232.2
# 2                      117021.304                         2666.1
# 3                      121447.373                         3057.3
# 4                      118609.115                         2846.5
# 5                      123350.546                         2815.9
# ..                            ...                            ...
# 206                    261570.777                         2658.6
# 207                    284658.209                         2381.4
# 208                    283979.814                         2487.4
# 209                    283979.814                         2807.7
# 210                    283979.814                         2807.7
#
#      Child malnutrition, underweight (% of under age 5)  ...  \
# 1                                                  1.7   ...
# 2                                                  1.7   ...
# 3                                                  1.7   ...
# 4                                                  1.7   ...
# 5                                                  1.7   ...
# ..                                                 ...   ...
# 206                                                3.5   ...
# 207                                                3.5   ...
# 208                                                3.5   ...
# 209                                                3.5   ...
# 210                                                3.5   ...
#
#      Physicians (per 1,000 people)  Population  Population growth (annual %)  \
# 1                         2.680000  32642442.0                      1.404532
# 2                         2.682000  33093579.0                      1.372593
# 3                         2.684000  33540023.0                      1.340017
# 4                         2.682667  33982035.0                      1.309256
# 5                         2.681333  34420352.0                      1.281601
# ..                             ...         ...                           ...
# 206                       1.560000  69063538.0                      1.341575
# 207                       1.505500  69992754.0                      1.336480
# 208                       1.451000  70923730.0                      1.321335
# 209                       1.640000  71846212.0                      1.292282
# 210                       1.640000  72752325.0                      1.253297
#
#      Population in urban agglomerations >1million (%)  \
# 1                                           39.204392
# 2                                           39.119646
# 3                                           39.042135
# 4                                           38.975668
# 5                                           38.920819
# ..                                                ...
# 206                                         28.690982
# 207                                         28.849141
# 208                                         28.975006
# 209                                         29.075349
# 210                                         29.155890
#
#      Population living below $1.25 a day (% of total)  \
# 1                                                0.13
# 2                                                0.13
# 3                                                0.13
# 4                                                0.49
# 5                                                0.85
# ..                                                ...
# 206                                              2.72
# 207                                              2.72
# 208                                              2.72
# 209                                              2.72
# 210                                              2.72
#
#      Primary completion rate, total (% of relevant age group)  \
# 1                                            100.00000
# 2                                            100.00000
# 3                                            100.00000
# 4                                            100.00000
# 5                                            100.00000
# ..                                                 ...
# 206                                           91.67677
# 207                                           91.05292
# 208                                           93.42516
# 209                                           93.42516
# 210                                           93.42516
#
#      Ratio of girls to boys in primary & secondary school (%)  \
# 1                                              100.000
# 2                                              100.000
# 3                                              100.000
# 4                                              100.000
# 5                                              100.000
# ..                                                 ...
# 206                                             90.077
# 207                                             90.963
# 208                                             92.875
# 209                                             92.875
# 210                                             92.875
#
#      Under-five mortality rate (per 1,000)  Urban population  \
# 1                                     26.9      2.839892e+07
# 2                                     25.8      2.890393e+07
# 3                                     24.9      2.940789e+07
# 4                                     24.2      2.991099e+07
# 5                                     23.4      3.041382e+07
# ..                                     ...               ...
# 206                                   25.1      4.679745e+07
# 207                                   22.8      4.774906e+07
# 208                                   21.0      4.871042e+07
# 209                                   19.1      4.967447e+07
# 210                                   17.6      5.063562e+07
#
#      Urban population growth (annual %)
# 1                              1.865363
# 2                              1.762636
# 3                              1.728544
# 4                              1.696280
# 5                              1.667133
# ..                                  ...
# 206                            2.022757
# 207                            2.013053
# 208                            1.993361
# 209                            1.959821
# 210                            1.916411
#
# [210 rows x 32 columns]

# %% [markdown]
# #### Check if still have missing value

# %%
for i in df_imputed.columns:
    data_missing = np.mean(df_imputed[i].isnull())
    print('{} - {}% , {}'.format(i, round(data_missing*100), df_imputed[i].isna().sum()))
# Out:
# Country code - 0% , 0
# Country name - 0% , 0
# Year - 0% , 0
# Access to improved sanitation (% of total pop.) - 0% , 0
# Access to improved water source (% of total pop.) - 10% , 21
# CO2 emissions per capita (metric tons) - 0% , 0
# CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $) - 0% , 0
# CO2 emissions, total (KtCO2) - 0% , 0
# Cereal yield (kg per hectare) - 0% , 0
# Child malnutrition, underweight (% of under age 5) - 10% , 21
# Energy use per capita (kilograms of oil equivalent) - 0% , 0
# Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $) - 0% , 0
# Foreign direct investment, net inflows (% of GDP) - 0% , 0
# GDP ($) - 0% , 0
# GHG net emissions/removals by LUCF (MtCO2e) - 0% , 0
# GNI per capita (Atlas $) - 0% , 0
# Invest. in energy w/ private participation ($) - 0% , 0
# Invest. in telecoms w/ private participation ($) - 0% , 0
# Invest. in transport w/ private participation ($) - 0% , 0
# Invest. in water/sanit. w/ private participation ($) - 0% , 0
# Nationally terrestrial protected areas (% of total land area) - 0% , 0
# Paved roads (% of total roads) - 0% , 0
# Physicians (per 1,000 people) - 0% , 0
# Population - 0% , 0
# Population growth (annual %) - 0% , 0
# Population in urban agglomerations >1million (%) - 0% , 0
# Population living below $1.25 a day (% of total) - 0% , 0
# Primary completion rate, total (% of relevant age group) - 0% , 0
# Ratio of girls to boys in primary & secondary school (%) - 0% , 0
# Under-five mortality rate (per 1,000) - 0% , 0
# Urban population - 0% , 0
# Urban population growth (annual %) - 0% , 0

# %% [markdown]
# There are still missing values for "Access to improved water source (% of total pop.)" and "Child malnutrition, underweight (% of under age 5)" as there is no value in other years to impute data

# %% [markdown]
# ## Data Analysis

# %%
id_candidates = ["Country code", "Country name", "Year"]
id_cols = [c for c in id_candidates if c in df_imputed.columns]
num_cols = [c for c in df_imputed.columns if c not in id_cols]

# interpret numeric for analysis computations 
numeric_cols = []
for c in num_cols:
    try:
        pd.to_numeric(df_imputed[c], errors="raise")
        numeric_cols.append(c)
    except Exception:
        pass

print("ID columns:", id_cols)
print("Numeric columns detected:", len(numeric_cols))
# Out:
# ID columns: ['Country code', 'Country name', 'Year']
# Numeric columns detected: 29

# %%
country_col = "Country name"
year_col = "Year"
co2_col = "CO2 emissions per capita (metric tons)"
energyuse_col ="Energy use per capita (kilograms of oil equivalent)"

# Sort values for cleaner plotting 
plot_df = df_imputed.sort_values(by=[country_col, year_col])

# Create a figure with 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))


# Plot 1: CO₂ emissions per capita over years

sb.lineplot(
    data=plot_df,
    x=year_col,
    y=co2_col,
    hue=country_col,
    marker="o",
    ax=axes[0]
)
axes[0].set_title("CO2 Emissions per Capita Over the Years (by Country)")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("CO₂ Emissions (metric tons)")
axes[0].legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")


# Plot 2: energy use per capita over years

sb.lineplot(
    data=plot_df,
    x=year_col,
    y=energyuse_col,
    hue=country_col,
    marker="s",
    ax=axes[1]
)
axes[1].set_title("Energy use per capita Over the Years (by Country)")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Energy use per capita)")
axes[1].legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")

# Layout adjustments

plt.suptitle("Trends of CO2 Emissions and Energy use per Capita Over Time by Country",
             fontsize=14, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_26996\2598483017.py:48: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# c:\Users\jason\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
country_col = "Country name"
year_col = "Year"
watersani_col = "Access to improved sanitation (% of total pop.)"
watersour_col ="Access to improved water source (% of total pop.)"

# Sort values for cleaner plotting 
plot_df = df_imputed.sort_values(by=[country_col, year_col])

# Create a figure with 2 subplots (side by side) 
fig, axes = plt.subplots(1, 2, figsize=(15, 6))


# Plot 1: Access to improved sanitation over years

sb.lineplot(
    data=plot_df,
    x=year_col,
    y=watersani_col,
    hue=country_col,
    marker="o",
    ax=axes[0]
)
axes[0].set_title("Access to improved sanitation Over the Years (by Country)")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Access to improved sanitation (% of total pop.)")
axes[0].legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")


# Plot 2: Access to improved water source over years

sb.lineplot(
    data=plot_df,
    x=year_col,
    y=watersour_col,
    hue=country_col,
    marker="s",
    ax=axes[1]
)
axes[1].set_title("Access to improved water source Over the Years (by Country)")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Access to improved water source (% of total pop.)")
axes[1].legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")

# Layout adjustments

plt.suptitle("Trends of Access to imoproved water sanitation and water source Over Time by Country",
             fontsize=14, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
climate_vars = ["CO2 emissions per capita (metric tons)", "Energy use per capita (kilograms of oil equivalent)", "Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $)", "GHG net emissions/removals by LUCF (MtCO2e)"]
living_vars  = ["Access to improved sanitation (% of total pop.)", "Cereal yield (kg per hectare)", "Foreign direct investment, net inflows (% of GDP)", "GDP ($)", "GNI per capita (Atlas $)","Invest. in energy w/ private participation ($)","Invest. in telecoms w/ private participation ($)","Invest. in transport w/ private participation ($)","Invest. in water/sanit. w/ private participation ($)","Nationally terrestrial protected areas (% of total land area)","Paved roads (% of total roads)","Under-five mortality rate (per 1,000)","Physicians (per 1,000 people)","Population","Population growth (annual %)"]

cols_to_use = [c for c in climate_vars + living_vars if c in df_imputed.columns]

# Compute correlation
corr_matrix = (
    df_imputed[cols_to_use]
    .corr(method="pearson", min_periods=30)  # ignore NaN
    .loc[[c for c in climate_vars if c in df_imputed.columns],
         [c for c in living_vars if c in df_imputed.columns]]
)

# %%
plt.figure(figsize=(18,10))   # wider and taller
sb.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="RdBu",
    center=0,
    linewidths=0.5,
    cbar_kws={'label': 'Correlation coefficient'}
)

# Rotate x labels and align neatly
plt.xticks(rotation=45, ha="right", fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.title("Correlation: Climate Change vs Living Standards", fontsize=14, fontweight="bold")
plt.xlabel("Living Standard Indicators", fontsize=12)
plt.ylabel("Climate Change Indicators", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Positive Relationship
# #### Improved living standards (higher GDP, infrastructure, access to resources) are still heavily dependent on energy use and fossil-fuel consumption — leading to higher emissions. Economic progress and industrialization are therefore closely tied to environmental impact.

# %% [markdown]
# ### Negative Relationship
# #### While economic growth raises living standards, unchecked emissions can harm environmental health and long-term sustainability, indirectly reducing quality of life through pollution, climate risk, and public health impacts.

# %% [markdown]
# ### Summary
# #### The positive correlations suggest that countries achieving better living standards (higher GDP, infrastructure, utilities) are also those emitting more CO₂ and consuming more energy.
#
# #### The negative correlations indicate that as emissions rise, sustainability and environmental quality decline, showing potential long-term threats to living conditions.
#
# #### This dual trend highlights the development–sustainability trade-off:
#
# #### Economic growth improves life in the short term but worsens climate conditions, which can threaten future well-being.

# %% [markdown]
# #### The correlation analysis demonstrates that improvements in living standards — reflected by higher GDP, better infrastructure, and increased access to services — are closely associated with higher energy use and CO₂ emissions. This suggests that economic growth remains heavily dependent on carbon-intensive development. However, the negative relationships with population growth and sanitation imply that excessive emissions may degrade environmental and social conditions over time. Therefore, while climate change and economic progress are currently intertwined, achieving sustainable living standards will require decoupling growth from emissions through cleaner energy and efficient infrastructure.

# %%
df_imputed.to_excel('Cleaned_Dataset.xlsx', index=False)
print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!
