# %% [markdown]
# ## Data Prep

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# #### Read data from different sheets

# %%
# Read sheets directly from the Excel file
file_path = "climate_change_download_0.xlsx"

Main_data = pd.read_excel(file_path, sheet_name="Data")       # main dataset
Country_data = pd.read_excel(file_path, sheet_name="Country") # region from another sheet

# Check the first few rows
Main_data.head()
# Out:
#   Country code Country name           Series code  \
# 0          AFG  Afghanistan        AG.LND.EL5M.ZS
# 1          AFG  Afghanistan     AG.LND.IRIG.AG.ZS
# 2          AFG  Afghanistan        AG.YLD.CREL.KG
# 3          AFG  Afghanistan  BX.KLT.DINV.WD.GD.ZS
# 4          AFG  Afghanistan        EG.ELC.ACCS.ZS
#
#                                          Series name SCALE Decimals    1990  \
# 0                Land area below 5m (% of land area)     0        1       0
# 1  Agricultural land under irrigation (% of total...     0        1      ..
# 2                      Cereal yield (kg per hectare)     0        0  1200.6
# 3  Foreign direct investment, net inflows (% of GDP)     0        1      ..
# 4      Access to electricity (% of total population)     0        1      ..
#
#    1991    1992    1993  ...      2002      2003      2004      2005  \
# 0    ..      ..      ..  ...        ..        ..        ..        ..
# 1    ..      ..      ..  ...  4.622149  7.259298  5.502361  5.840148
# 2  1160  1097.7  1135.5  ...    1669.7      1458    1334.8    1790.4
# 3    ..      ..      ..  ...  1.152364  1.212725  3.276532  3.976666
# 4    ..      ..      ..  ...        ..        ..        ..        ..
#
#        2006      2007      2008      2009 2010 2011
# 0        ..        ..        ..        ..   ..   ..
# 1  6.085466  5.940385  5.779478  4.843049   ..   ..
# 2    1551.6    1913.5    1418.1    2031.3   ..   ..
# 3   3.08213  2.495036  2.551583        ..   ..   ..
# 4        ..        ..        ..      15.6   ..   ..
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Merge information from different sheet

# %%
# Identify the column names for matching
data_code_col = "Country code"      
country_code_col = "Country code"   
region_col = "Region"               

# Merge Region column into Main_data
Main_data = Main_data.merge(
    Country_data[[country_code_col, region_col]],
    how="left",
    left_on=data_code_col,
    right_on=country_code_col
)

# %% [markdown]
# #### Convert "Year" to long format

# %%
Main_data_long = Main_data.melt(
    id_vars=["Country code", "Country name", "Series code", "Series name", "SCALE", "Decimals", "Region"],      # columns to keep
    var_name="Year",       # new column for former year column names
    value_name="Value"     # new column for values
)

# Convert Year to numeric 
Main_data_long["Year"] = pd.to_numeric(Main_data_long["Year"], errors="coerce")

Main_data_long.head()
# Out:
#   Country code Country name           Series code  \
# 0          AFG  Afghanistan        AG.LND.EL5M.ZS
# 1          AFG  Afghanistan     AG.LND.IRIG.AG.ZS
# 2          AFG  Afghanistan        AG.YLD.CREL.KG
# 3          AFG  Afghanistan  BX.KLT.DINV.WD.GD.ZS
# 4          AFG  Afghanistan        EG.ELC.ACCS.ZS
#
#                                          Series name SCALE Decimals  \
# 0                Land area below 5m (% of land area)     0        1
# 1  Agricultural land under irrigation (% of total...     0        1
# 2                      Cereal yield (kg per hectare)     0        0
# 3  Foreign direct investment, net inflows (% of GDP)     0        1
# 4      Access to electricity (% of total population)     0        1
#
#        Region  Year   Value
# 0  South Asia  1990       0
# 1  South Asia  1990      ..
# 2  South Asia  1990  1200.6
# 3  South Asia  1990      ..
# 4  South Asia  1990      ..

# %% [markdown]
# #### Convert "Series name" to wide format

# %%
# Convert Value to numeric (non-numeric will become NaN)
Main_data_long['Value'] = pd.to_numeric(Main_data_long['Value'], errors='coerce')

# Then pivot normally
df_wide = Main_data_long.pivot_table(
    index=['Country code', 'Country name', 'Region', 'Year'],
    columns='Series name',
    values='Value',
    aggfunc='first'   # use 'first' to avoid mean aggregation
).reset_index()

# Remove the column name hierarchy
df_wide.columns.name = None

# Show output
df_wide.head()
# Out:
#   Country code Country name                     Region  Year  \
# 0          ABW        Aruba  Latin America & Caribbean  1990
# 1          ABW        Aruba  Latin America & Caribbean  1991
# 2          ABW        Aruba  Latin America & Caribbean  1992
# 3          ABW        Aruba  Latin America & Caribbean  1993
# 4          ABW        Aruba  Latin America & Caribbean  1994
#
#    Access to electricity (% of total population)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Access to improved sanitation (% of total pop.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Access to improved water source (% of total pop.)  \
# 0                                              100.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural land under irrigation (% of total ag. land)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annual freshwater withdrawals (% of internal resources)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Average annual precipitation (1961-1990, mm)  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
#
#    Population below 5m (% of total)  Population growth (annual %)  \
# 0                          29.57482                      1.820254
# 1                               NaN                      3.936181
# 2                               NaN                      5.484041
# 3                               NaN                      6.088818
# 4                               NaN                      5.611677
#
#    Population in urban agglomerations >1million (%)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Population living below $1.25 a day (% of total)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Primary completion rate, total (% of relevant age group)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Public sector mgmt & institutions avg. (1-6 scale; 6=best)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Ratio of girls to boys in primary & secondary school (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Under-five mortality rate (per 1,000)  Urban population  \
# 0                                    NaN         31259.941
# 1                                    NaN         32321.000
# 2                                    NaN         33938.142
# 3                                    NaN         35851.062
# 4                                    NaN         37690.142
#
#    Urban population growth (annual %)
# 0                            1.780501
# 1                            3.337974
# 2                            4.882234
# 3                            5.483368
# 4                            5.002538
#
# [5 rows x 52 columns]

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5085 entries, 0 to 5084
# Data columns (total 52 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Country code                                                      5085 non-null   object
#  1   Country name                                                      5085 non-null   object
#  2   Region                                                            5085 non-null   object
#  3   Year                                                              5085 non-null   int64
#  4   Access to electricity (% of total population)                     99 non-null     float64
#  5   Access to improved sanitation (% of total pop.)                   968 non-null    float64
#  6   Access to improved water source (% of total pop.)                 988 non-null    float64
#  7   Agricultural land under irrigation (% of total ag. land)          442 non-null    float64
#  8   Annual freshwater withdrawals (% of internal resources)           281 non-null    float64
#  9   Average annual precipitation (1961-1990, mm)                      200 non-null    float64
#  10  CO2 emissions per capita (metric tons)                            3980 non-null   float64
#  11  CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)          3569 non-null   float64
#  12  CO2 emissions, total (KtCO2)                                      3983 non-null   float64
#  13  Cereal yield (kg per hectare)                                     3749 non-null   float64
#  14  Child malnutrition, underweight (% of under age 5)                524 non-null    float64
#  15  Disaster risk reduction progress score (1-5 scale; 5=best)        84 non-null     float64
#  16  Droughts, floods, extreme temps (% pop. avg. 1990-2009)           168 non-null    float64
#  17  Ease of doing business (ranking 1-183; 1=best)                    546 non-null    float64
#  18  Energy use per capita (kilograms of oil equivalent)               3170 non-null   float64
#  19  Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $)     3044 non-null   float64
#  20  Foreign direct investment, net inflows (% of GDP)                 4015 non-null   float64
#  21  GDP ($)                                                           4347 non-null   float64
#  22  GHG net emissions/removals by LUCF (MtCO2e)                       943 non-null    float64
#  23  GNI per capita (Atlas $)                                          4113 non-null   float64
#  24  Hosted Clean Development Mechanism (CDM) projects                 92 non-null     float64
#  25  Hosted Joint Implementation (JI) projects                         17 non-null     float64
#  26  Invest. in energy w/ private participation ($)                    855 non-null    float64
#  27  Invest. in telecoms w/ private participation ($)                  1925 non-null   float64
#  28  Invest. in transport w/ private participation ($)                 546 non-null    float64
#  29  Invest. in water/sanit. w/ private participation ($)              324 non-null    float64
#  30  Issued Certified Emission Reductions (CERs) from CDM (thousands)  75 non-null     float64
#  31  Issued Emission Reduction Units (ERUs) from JI (thousands)        8 non-null      float64
#  32  Land area below 5m (% of land area)                               454 non-null    float64
#  33  Malaria incidence rate (per 100,000 people)                       110 non-null    float64
#  34  Methane (CH4) emissions, total (KtCO2e)                           600 non-null    float64
#  35  Nationally terrestrial protected areas (% of total land area)     4400 non-null   float64
#  36  Nitrous oxide (N2O) emissions, total (KtCO2e)                     600 non-null    float64
#  37  Nurses and midwives (per 1,000 people)                            376 non-null    float64
#  38  Other GHG emissions, total (KtCO2e)                               584 non-null    float64
#  39  Paved roads (% of total roads)                                    2037 non-null   float64
#  40  Physicians (per 1,000 people)                                     1653 non-null   float64
#  41  Population                                                        4874 non-null   float64
#  42  Population below 5m (% of total)                                  454 non-null    float64
#  43  Population growth (annual %)                                      4848 non-null   float64
#  44  Population in urban agglomerations >1million (%)                  2544 non-null   float64
#  45  Population living below $1.25 a day (% of total)                  568 non-null    float64
#  46  Primary completion rate, total (% of relevant age group)          2334 non-null   float64
#  47  Public sector mgmt & institutions avg. (1-6 scale; 6=best)        458 non-null    float64
#  48  Ratio of girls to boys in primary & secondary school (%)          2673 non-null   float64
#  49  Under-five mortality rate (per 1,000)                             4410 non-null   float64
#  50  Urban population                                                  4659 non-null   float64
#  51  Urban population growth (annual %)                                4636 non-null   float64
# dtypes: float64(48), int64(1), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Find percentage of missing value in the data

# %%
# Calculate missing values count and percentage
missing_count = df_wide.isnull().sum()
missing_percent = (missing_count / len(df_wide)) * 100

# Combine into a single DataFrame
missing_table = pd.DataFrame({
    'Missing Count': missing_count,
    'Missing %': missing_percent
}).sort_values(by='Missing %', ascending=False)

missing_table.head(48)
# Out:
#                                                     Missing Count  Missing %
# Issued Emission Reduction Units (ERUs) from JI ...           5077  99.842675
# Hosted Joint Implementation (JI) projects                    5068  99.665683
# Issued Certified Emission Reductions (CERs) fro...           5010  98.525074
# Disaster risk reduction progress score (1-5 sca...           5001  98.348083
# Hosted Clean Development Mechanism (CDM) projects            4993  98.190757
# Access to electricity (% of total population)                4986  98.053097
# Malaria incidence rate (per 100,000 people)                  4975  97.836775
# Droughts, floods, extreme temps (% pop. avg. 19...           4917  96.696165
# Average annual precipitation (1961-1990, mm)                 4885  96.066863
# Annual freshwater withdrawals (% of internal re...           4804  94.473943
# Invest. in water/sanit. w/ private participatio...           4761  93.628319
# Nurses and midwives (per 1,000 people)                       4709  92.605703
# Agricultural land under irrigation (% of total ...           4643  91.307768
# Land area below 5m (% of land area)                          4631  91.071780
# Population below 5m (% of total)                             4631  91.071780
# Public sector mgmt & institutions avg. (1-6 sca...           4627  90.993117
# Child malnutrition, underweight (% of under age 5)           4561  89.695182
# Invest. in transport w/ private participation ($)            4539  89.262537
# Ease of doing business (ranking 1-183; 1=best)               4539  89.262537
# Population living below $1.25 a day (% of total)             4517  88.829892
# Other GHG emissions, total (KtCO2e)                          4501  88.515241
# Methane (CH4) emissions, total (KtCO2e)                      4485  88.200590
# Nitrous oxide (N2O) emissions, total (KtCO2e)                4485  88.200590
# Invest. in energy w/ private participation ($)               4230  83.185841
# GHG net emissions/removals by LUCF (MtCO2e)                  4142  81.455261
# Access to improved sanitation (% of total pop.)              4117  80.963618
# Access to improved water source (% of total pop.)            4097  80.570305
# Physicians (per 1,000 people)                                3432  67.492625
# Invest. in telecoms w/ private participation ($)             3160  62.143559
# Paved roads (% of total roads)                               3048  59.941003
# Primary completion rate, total (% of relevant a...           2751  54.100295
# Population in urban agglomerations >1million (%)             2541  49.970501
# Ratio of girls to boys in primary & secondary s...           2412  47.433628
# Energy use per units of GDP (kg oil eq./$1,000 ...           2041  40.137660
# Energy use per capita (kilograms of oil equival...           1915  37.659784
# CO2 emissions per units of GDP (kg/$1,000 of 20...           1516  29.813176
# Cereal yield (kg per hectare)                                1336  26.273353
# CO2 emissions per capita (metric tons)                       1105  21.730580
# CO2 emissions, total (KtCO2)                                 1102  21.671583
# Foreign direct investment, net inflows (% of GDP)            1070  21.042281
# GNI per capita (Atlas $)                                      972  19.115044
# GDP ($)                                                       738  14.513274
# Nationally terrestrial protected areas (% of to...            685  13.470993
# Under-five mortality rate (per 1,000)                         675  13.274336
# Urban population growth (annual %)                            449   8.829892
# Urban population                                              426   8.377581
# Population growth (annual %)                                  237   4.660767
# Population                                                    211   4.149459

# %% [markdown]
# Many sustainability and health indicators are sparse, while economic and demographic data are relatively complete

# %% [markdown]
# #### Find the country with least missing data

# %%
# Compute % missing data per country (modern syntax)
missing_data_country = (
    df_wide.groupby("Country name", group_keys=False)
    .apply(lambda x: x.drop(columns=["Country name"], errors="ignore")
                     .isna().mean().mean() * 100)
)

# Sort by least missing data
least_missing = missing_data_country.sort_values(ascending=True)

# Show top 10
print(least_missing.head(10))
# Out:
# Country name
# Mexico       46.969697
# Indonesia    48.306595
# Poland       48.395722
# Malaysia     49.286988
# Colombia     49.554367
# Turkey       49.821747
# India        49.821747
# Chile        49.821747
# Romania      49.910873
# Argentina    49.910873
# dtype: float64
# C:\Users\jason\AppData\Local\Temp\ipykernel_21756\3819671603.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.drop(columns=["Country name"], errors="ignore")

# %%
# Define the top 10 countries (least missing data)
top10_countries = [
    "Mexico", "Indonesia", "Poland", "Malaysia", "Colombia",
    "Turkey", "India", "Chile", "Romania", "Argentina"
]

# Filter only those countries
df_filtered = df_wide[df_wide["Country name"].isin(top10_countries)]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Sanity checks

# %%
print("Rows, Cols:", df_filtered.shape)
print("Duplicate rows:", df_filtered.duplicated().sum())
print("\nDtypes:")
print(df_filtered.dtypes.head(12))
# Out:
# Rows, Cols: (220, 52)
# Duplicate rows: 0
#
# Dtypes:
# Country code                                                 object
# Country name                                                 object
# Region                                                       object
# Year                                                          int64
# Access to electricity (% of total population)               float64
# Access to improved sanitation (% of total pop.)             float64
# Access to improved water source (% of total pop.)           float64
# Agricultural land under irrigation (% of total ag. land)    float64
# Annual freshwater withdrawals (% of internal resources)     float64
# Average annual precipitation (1961-1990, mm)                float64
# CO2 emissions per capita (metric tons)                      float64
# CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)    float64
# dtype: object

# %% [markdown]
# #### Replace missing value

# %%
missing_tokens = {"..", "NA", "N/A", "na", "n/a", "", "—", "-"}

df_filtered = df_filtered.copy()

for c in df_filtered.columns:
    if df_filtered[c].dtype == "object":
        df_filtered.loc[:, c] = df_filtered[c].replace(list(missing_tokens), np.nan)

# %% [markdown]
# #### Percentage of missiing data in each column

# %%
missing_by_col = df_filtered[metric_cols].isna().mean().sort_values(ascending=False) * 100
missing_summary = (missing_by_col.round(2)
                   .rename("Missing %")
                   .reset_index()
                   .rename(columns={"index": "Column"}))
missing_summary.head(20)
# Out:
#                                                Column  Missing %
# 0   Issued Certified Emission Reductions (CERs) fr...     100.00
# 1   Issued Emission Reduction Units (ERUs) from JI...      99.55
# 2           Hosted Joint Implementation (JI) projects      99.09
# 3       Access to electricity (% of total population)      97.27
# 4   Hosted Clean Development Mechanism (CDM) projects      96.82
# 5         Malaria incidence rate (per 100,000 people)      96.82
# 6   Public sector mgmt & institutions avg. (1-6 sc...      96.36
# 7   Disaster risk reduction progress score (1-5 sc...      95.91
# 8   Droughts, floods, extreme temps (% pop. avg. 1...      95.45
# 9        Average annual precipitation (1961-1990, mm)      95.45
# 10             Nurses and midwives (per 1,000 people)      91.82
# 11                Land area below 5m (% of land area)      90.91
# 12  Annual freshwater withdrawals (% of internal r...      90.91
# 13                   Population below 5m (% of total)      90.91
# 14     Ease of doing business (ranking 1-183; 1=best)      86.36
# 15                Other GHG emissions, total (KtCO2e)      81.82
# 16            Methane (CH4) emissions, total (KtCO2e)      81.82
# 17      Nitrous oxide (N2O) emissions, total (KtCO2e)      81.82
# 18  Agricultural land under irrigation (% of total...      81.36
# 19  Access to improved water source (% of total pop.)      79.55

# %% [markdown]
# #### Drop column with missing value>0.80

# %%
drop_threshold = 0.80  # drop columns with >=70% missing; adjust as needed
cols_to_drop = missing_by_col[missing_by_col >= drop_threshold*100].index.tolist()
df_reduced = df_filtered.drop(columns=cols_to_drop)

print("Dropped columns (>=80% missing):", len(cols_to_drop))
cols_to_drop[:]  # preview
# Out:
# Dropped columns (>=80% missing): 19
# ['Issued Certified Emission Reductions (CERs) from CDM (thousands)',
#  'Issued Emission Reduction Units (ERUs) from JI (thousands)',
#  'Hosted Joint Implementation (JI) projects',
#  'Access to electricity (% of total population)',
#  'Hosted Clean Development Mechanism (CDM) projects',
#  'Malaria incidence rate (per 100,000 people)',
#  'Public sector mgmt & institutions avg. (1-6 scale; 6=best)',
#  'Disaster risk reduction progress score (1-5 scale; 5=best)',
#  'Droughts, floods, extreme temps (% pop. avg. 1990-2009)',
#  'Average annual precipitation (1961-1990, mm)',
#  'Nurses and midwives (per 1,000 people)',
#  'Land area below 5m (% of land area)',
#  'Annual freshwater withdrawals (% of internal resources)',
#  'Population below 5m (% of total)',
#  'Ease of doing business (ranking 1-183; 1=best)',
#  'Other GHG emissions, total (KtCO2e)',
#  'Methane (CH4) emissions, total (KtCO2e)',
#  'Nitrous oxide (N2O) emissions, total (KtCO2e)',
#  'Agricultural land under irrigation (% of total ag. land)']

# %%
metrics_kept = [c for c in df_reduced.columns if c not in id_cols + ["Year"]]
mask_all_nan = df_reduced[metrics_kept].isna().all(axis=1)
print("Rows removed (all metrics NaN):", int(mask_all_nan.sum()))
df_reduced = df_reduced[~mask_all_nan]
df_reduced.shape
# Out:
# Rows removed (all metrics NaN): 10
# (210, 33)

# %% [markdown]
# #### Impute missing value

# %%
def impute_group(g):
    g = g.sort_values("Year")
    g[metrics_kept] = g[metrics_kept].interpolate(method="linear", limit_direction="both")
    g[metrics_kept] = g[metrics_kept].ffill().bfill()
    return g

df_imputed = df_reduced.groupby("Country name", group_keys=False).apply(impute_group)
df_imputed.shape
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_21756\94145776.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_imputed = df_reduced.groupby("Country name", group_keys=False).apply(impute_group)
# (210, 33)

# %% [markdown]
# #### Keep the data in within the logical limit

# %%
percent_like = [c for c in metrics_kept if "%" in c]
for c in percent_like:
    df_imputed[c] = df_imputed[c].clip(lower=0, upper=100)
percent_like[:10]  # preview clipped columns
# Out:
# ['Access to improved sanitation (% of total pop.)',
#  'Access to improved water source (% of total pop.)',
#  'Child malnutrition, underweight (% of under age 5)',
#  'Foreign direct investment, net inflows (% of GDP)',
#  'Nationally terrestrial protected areas (% of total land area)',
#  'Paved roads (% of total roads)',
#  'Population growth (annual %)',
#  'Population in urban agglomerations >1million (%)',
#  'Population living below $1.25 a day (% of total)',
#  'Primary completion rate, total (% of relevant age group)']

# %%
df_imputed
# Out:
#      Country code Country name                     Region  Year  \
# 131           ARG    Argentina  Latin America & Caribbean  1990
# 132           ARG    Argentina  Latin America & Caribbean  1991
# 133           ARG    Argentina  Latin America & Caribbean  1992
# 134           ARG    Argentina  Latin America & Caribbean  1993
# 135           ARG    Argentina  Latin America & Caribbean  1994
# ...           ...          ...                        ...   ...
# 4619          TUR       Turkey      Europe & Central Asia  2006
# 4620          TUR       Turkey      Europe & Central Asia  2007
# 4621          TUR       Turkey      Europe & Central Asia  2008
# 4622          TUR       Turkey      Europe & Central Asia  2009
# 4623          TUR       Turkey      Europe & Central Asia  2010
#
#       Access to improved sanitation (% of total pop.)  \
# 131                                         90.000000
# 132                                         90.200000
# 133                                         90.400000
# 134                                         90.600000
# 135                                         90.800000
# ...                                               ...
# 4619                                        89.333333
# 4620                                        89.666667
# 4621                                        90.000000
# 4622                                        90.000000
# 4623                                        90.000000
#
#       Access to improved water source (% of total pop.)  \
# 131                                           94.000000
# 132                                           94.200000
# 133                                           94.400000
# 134                                           94.600000
# 135                                           94.800000
# ...                                                 ...
# 4619                                          97.666667
# 4620                                          98.333333
# 4621                                          99.000000
# 4622                                          99.000000
# 4623                                          99.000000
#
#       CO2 emissions per capita (metric tons)  \
# 131                                 3.449913
# 132                                 3.536073
# 133                                 3.620969
# 134                                 3.490348
# 135                                 3.583651
# ...                                      ...
# 4619                                3.787393
# 4620                                4.066967
# 4621                                4.004017
# 4622                                4.004017
# 4623                                4.004017
#
#       CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)  \
# 131                                          462.560560
# 132                                          426.614517
# 133                                          395.521880
# 134                                          364.733889
# 135                                          358.397431
# ...                                                 ...
# 4619                                         313.221530
# 4620                                         325.664011
# 4621                                         322.761413
# 4622                                         322.761413
# 4623                                         322.761413
#
#       CO2 emissions, total (KtCO2)  Cereal yield (kg per hectare)  ...  \
# 131                     112613.570                         2232.2  ...
# 132                     117021.304                         2666.1  ...
# 133                     121447.373                         3057.3  ...
# 134                     118609.115                         2846.5  ...
# 135                     123350.546                         2815.9  ...
# ...                            ...                            ...  ...
# 4619                    261570.777                         2658.6  ...
# 4620                    284658.209                         2381.4  ...
# 4621                    283979.814                         2487.4  ...
# 4622                    283979.814                         2807.7  ...
# 4623                    283979.814                         2807.7  ...
#
#       Physicians (per 1,000 people)  Population  Population growth (annual %)  \
# 131                        2.680000  32642442.0                      1.404532
# 132                        2.682000  33093579.0                      1.372593
# 133                        2.684000  33540023.0                      1.340017
# 134                        2.682667  33982035.0                      1.309256
# 135                        2.681333  34420352.0                      1.281601
# ...                             ...         ...                           ...
# 4619                       1.560000  69063538.0                      1.341575
# 4620                       1.505500  69992754.0                      1.336480
# 4621                       1.451000  70923730.0                      1.321335
# 4622                       1.640000  71846212.0                      1.292282
# 4623                       1.640000  72752325.0                      1.253297
#
#       Population in urban agglomerations >1million (%)  \
# 131                                          39.204392
# 132                                          39.119646
# 133                                          39.042135
# 134                                          38.975668
# 135                                          38.920819
# ...                                                ...
# 4619                                         28.690982
# 4620                                         28.849141
# 4621                                         28.975006
# 4622                                         29.075349
# 4623                                         29.155890
#
#       Population living below $1.25 a day (% of total)  \
# 131                                               0.13
# 132                                               0.13
# 133                                               0.13
# 134                                               0.49
# 135                                               0.85
# ...                                                ...
# 4619                                              2.72
# 4620                                              2.72
# 4621                                              2.72
# 4622                                              2.72
# 4623                                              2.72
#
#       Primary completion rate, total (% of relevant age group)  \
# 131                                           100.00000
# 132                                           100.00000
# 133                                           100.00000
# 134                                           100.00000
# 135                                           100.00000
# ...                                                 ...
# 4619                                           91.67677
# 4620                                           91.05292
# 4621                                           93.42516
# 4622                                           93.42516
# 4623                                           93.42516
#
#       Ratio of girls to boys in primary & secondary school (%)  \
# 131                                             100.000
# 132                                             100.000
# 133                                             100.000
# 134                                             100.000
# 135                                             100.000
# ...                                                 ...
# 4619                                             90.077
# 4620                                             90.963
# 4621                                             92.875
# 4622                                             92.875
# 4623                                             92.875
#
#       Under-five mortality rate (per 1,000)  Urban population  \
# 131                                    26.9      2.839892e+07
# 132                                    25.8      2.890393e+07
# 133                                    24.9      2.940789e+07
# 134                                    24.2      2.991099e+07
# 135                                    23.4      3.041382e+07
# ...                                     ...               ...
# 4619                                   25.1      4.679745e+07
# 4620                                   22.8      4.774906e+07
# 4621                                   21.0      4.871042e+07
# 4622                                   19.1      4.967447e+07
# 4623                                   17.6      5.063562e+07
#
#       Urban population growth (annual %)
# 131                             1.865363
# 132                             1.762636
# 133                             1.728544
# 134                             1.696280
# 135                             1.667133
# ...                                  ...
# 4619                            2.022757
# 4620                            2.013053
# 4621                            1.993361
# 4622                            1.959821
# 4623                            1.916411
#
# [210 rows x 33 columns]

# %%
df_imputed = df_imputed.reset_index(drop=True)
df_imputed.index = df_imputed.index + 1

# %%
df_imputed
# Out:
#     Country code Country name                     Region  Year  \
# 1            ARG    Argentina  Latin America & Caribbean  1990
# 2            ARG    Argentina  Latin America & Caribbean  1991
# 3            ARG    Argentina  Latin America & Caribbean  1992
# 4            ARG    Argentina  Latin America & Caribbean  1993
# 5            ARG    Argentina  Latin America & Caribbean  1994
# ..           ...          ...                        ...   ...
# 206          TUR       Turkey      Europe & Central Asia  2006
# 207          TUR       Turkey      Europe & Central Asia  2007
# 208          TUR       Turkey      Europe & Central Asia  2008
# 209          TUR       Turkey      Europe & Central Asia  2009
# 210          TUR       Turkey      Europe & Central Asia  2010
#
#      Access to improved sanitation (% of total pop.)  \
# 1                                          90.000000
# 2                                          90.200000
# 3                                          90.400000
# 4                                          90.600000
# 5                                          90.800000
# ..                                               ...
# 206                                        89.333333
# 207                                        89.666667
# 208                                        90.000000
# 209                                        90.000000
# 210                                        90.000000
#
#      Access to improved water source (% of total pop.)  \
# 1                                            94.000000
# 2                                            94.200000
# 3                                            94.400000
# 4                                            94.600000
# 5                                            94.800000
# ..                                                 ...
# 206                                          97.666667
# 207                                          98.333333
# 208                                          99.000000
# 209                                          99.000000
# 210                                          99.000000
#
#      CO2 emissions per capita (metric tons)  \
# 1                                  3.449913
# 2                                  3.536073
# 3                                  3.620969
# 4                                  3.490348
# 5                                  3.583651
# ..                                      ...
# 206                                3.787393
# 207                                4.066967
# 208                                4.004017
# 209                                4.004017
# 210                                4.004017
#
#      CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)  \
# 1                                           462.560560
# 2                                           426.614517
# 3                                           395.521880
# 4                                           364.733889
# 5                                           358.397431
# ..                                                 ...
# 206                                         313.221530
# 207                                         325.664011
# 208                                         322.761413
# 209                                         322.761413
# 210                                         322.761413
#
#      CO2 emissions, total (KtCO2)  Cereal yield (kg per hectare)  ...  \
# 1                      112613.570                         2232.2  ...
# 2                      117021.304                         2666.1  ...
# 3                      121447.373                         3057.3  ...
# 4                      118609.115                         2846.5  ...
# 5                      123350.546                         2815.9  ...
# ..                            ...                            ...  ...
# 206                    261570.777                         2658.6  ...
# 207                    284658.209                         2381.4  ...
# 208                    283979.814                         2487.4  ...
# 209                    283979.814                         2807.7  ...
# 210                    283979.814                         2807.7  ...
#
#      Physicians (per 1,000 people)  Population  Population growth (annual %)  \
# 1                         2.680000  32642442.0                      1.404532
# 2                         2.682000  33093579.0                      1.372593
# 3                         2.684000  33540023.0                      1.340017
# 4                         2.682667  33982035.0                      1.309256
# 5                         2.681333  34420352.0                      1.281601
# ..                             ...         ...                           ...
# 206                       1.560000  69063538.0                      1.341575
# 207                       1.505500  69992754.0                      1.336480
# 208                       1.451000  70923730.0                      1.321335
# 209                       1.640000  71846212.0                      1.292282
# 210                       1.640000  72752325.0                      1.253297
#
#      Population in urban agglomerations >1million (%)  \
# 1                                           39.204392
# 2                                           39.119646
# 3                                           39.042135
# 4                                           38.975668
# 5                                           38.920819
# ..                                                ...
# 206                                         28.690982
# 207                                         28.849141
# 208                                         28.975006
# 209                                         29.075349
# 210                                         29.155890
#
#      Population living below $1.25 a day (% of total)  \
# 1                                                0.13
# 2                                                0.13
# 3                                                0.13
# 4                                                0.49
# 5                                                0.85
# ..                                                ...
# 206                                              2.72
# 207                                              2.72
# 208                                              2.72
# 209                                              2.72
# 210                                              2.72
#
#      Primary completion rate, total (% of relevant age group)  \
# 1                                            100.00000
# 2                                            100.00000
# 3                                            100.00000
# 4                                            100.00000
# 5                                            100.00000
# ..                                                 ...
# 206                                           91.67677
# 207                                           91.05292
# 208                                           93.42516
# 209                                           93.42516
# 210                                           93.42516
#
#      Ratio of girls to boys in primary & secondary school (%)  \
# 1                                              100.000
# 2                                              100.000
# 3                                              100.000
# 4                                              100.000
# 5                                              100.000
# ..                                                 ...
# 206                                             90.077
# 207                                             90.963
# 208                                             92.875
# 209                                             92.875
# 210                                             92.875
#
#      Under-five mortality rate (per 1,000)  Urban population  \
# 1                                     26.9      2.839892e+07
# 2                                     25.8      2.890393e+07
# 3                                     24.9      2.940789e+07
# 4                                     24.2      2.991099e+07
# 5                                     23.4      3.041382e+07
# ..                                     ...               ...
# 206                                   25.1      4.679745e+07
# 207                                   22.8      4.774906e+07
# 208                                   21.0      4.871042e+07
# 209                                   19.1      4.967447e+07
# 210                                   17.6      5.063562e+07
#
#      Urban population growth (annual %)
# 1                              1.865363
# 2                              1.762636
# 3                              1.728544
# 4                              1.696280
# 5                              1.667133
# ..                                  ...
# 206                            2.022757
# 207                            2.013053
# 208                            1.993361
# 209                            1.959821
# 210                            1.916411
#
# [210 rows x 33 columns]

# %% [markdown]
# #### Check if still have missing value

# %%
for i in df_imputed.columns:
    data_missing = np.mean(df_imputed[i].isnull())
    print('{} - {}% , {}'.format(i, round(data_missing*100), df_imputed[i].isna().sum()))
# Out:
# Country code - 0% , 0
# Country name - 0% , 0
# Region - 0% , 0
# Year - 0% , 0
# Access to improved sanitation (% of total pop.) - 0% , 0
# Access to improved water source (% of total pop.) - 10% , 21
# CO2 emissions per capita (metric tons) - 0% , 0
# CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $) - 0% , 0
# CO2 emissions, total (KtCO2) - 0% , 0
# Cereal yield (kg per hectare) - 0% , 0
# Child malnutrition, underweight (% of under age 5) - 10% , 21
# Energy use per capita (kilograms of oil equivalent) - 0% , 0
# Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $) - 0% , 0
# Foreign direct investment, net inflows (% of GDP) - 0% , 0
# GDP ($) - 0% , 0
# GHG net emissions/removals by LUCF (MtCO2e) - 0% , 0
# GNI per capita (Atlas $) - 0% , 0
# Invest. in energy w/ private participation ($) - 0% , 0
# Invest. in telecoms w/ private participation ($) - 0% , 0
# Invest. in transport w/ private participation ($) - 0% , 0
# Invest. in water/sanit. w/ private participation ($) - 0% , 0
# Nationally terrestrial protected areas (% of total land area) - 0% , 0
# Paved roads (% of total roads) - 0% , 0
# Physicians (per 1,000 people) - 0% , 0
# Population - 0% , 0
# Population growth (annual %) - 0% , 0
# Population in urban agglomerations >1million (%) - 0% , 0
# Population living below $1.25 a day (% of total) - 0% , 0
# Primary completion rate, total (% of relevant age group) - 0% , 0
# Ratio of girls to boys in primary & secondary school (%) - 0% , 0
# Under-five mortality rate (per 1,000) - 0% , 0
# Urban population - 0% , 0
# Urban population growth (annual %) - 0% , 0

# %% [markdown]
# There are still missing values for "Access to improved water source (% of total pop.)" and "Child malnutrition, underweight (% of under age 5)" as there is no value in other years to impute data

# %% [markdown]
# #### Data Analysis

# %%
id_candidates = ["Country code", "Country name", "Region", "Year"]
id_cols = [c for c in id_candidates if c in df_imputed.columns]
num_cols = [c for c in df_imputed.columns if c not in id_cols]

# Try to interpret numeric for analysis computations (without changing df)
numeric_cols = []
for c in num_cols:
    try:
        pd.to_numeric(df_imputed[c], errors="raise")
        numeric_cols.append(c)
    except Exception:
        pass

print("ID columns:", id_cols)
print("Numeric columns detected:", len(numeric_cols))
# Out:
# ID columns: ['Country code', 'Country name', 'Region', 'Year']
# Numeric columns detected: 29

# %%
df_imputed.to_excel("check.xlsx", index=False)
print("Cleaned data exported to Main_data_cleaned.xlsx")
# Out:
# Cleaned data exported to Main_data_cleaned.xlsx

# %%
corr = df_imputed[numeric_cols].corr(numeric_only=True)
corr.round(2).head(10)
# Out:
#                                                     Access to improved sanitation (% of total pop.)  \
# Access to improved sanitation (% of total pop.)                                                1.00
# Access to improved water source (% of total pop.)                                              0.88
# CO2 emissions per capita (metric tons)                                                         0.66
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                            -0.16
# CO2 emissions, total (KtCO2)                                                                  -0.68
# Cereal yield (kg per hectare)                                                                  0.22
# Child malnutrition, underweight (% of under age 5)                                            -0.84
# Energy use per capita (kilograms of oil equival...                                             0.72
# Energy use per units of GDP (kg oil eq./$1,000 ...                                            -0.49
# Foreign direct investment, net inflows (% of GDP)                                              0.41
#
#                                                     Access to improved water source (% of total pop.)  \
# Access to improved sanitation (% of total pop.)                                                  0.88
# Access to improved water source (% of total pop.)                                                1.00
# CO2 emissions per capita (metric tons)                                                           0.78
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                               0.04
# CO2 emissions, total (KtCO2)                                                                    -0.35
# Cereal yield (kg per hectare)                                                                    0.08
# Child malnutrition, underweight (% of under age 5)                                              -0.70
# Energy use per capita (kilograms of oil equival...                                               0.81
# Energy use per units of GDP (kg oil eq./$1,000 ...                                              -0.42
# Foreign direct investment, net inflows (% of GDP)                                                0.40
#
#                                                     CO2 emissions per capita (metric tons)  \
# Access to improved sanitation (% of total pop.)                                       0.66
# Access to improved water source (% of total pop.)                                     0.78
# CO2 emissions per capita (metric tons)                                                1.00
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                    0.54
# CO2 emissions, total (KtCO2)                                                         -0.25
# Cereal yield (kg per hectare)                                                        -0.03
# Child malnutrition, underweight (% of under age 5)                                   -0.49
# Energy use per capita (kilograms of oil equival...                                    0.97
# Energy use per units of GDP (kg oil eq./$1,000 ...                                    0.15
# Foreign direct investment, net inflows (% of GDP)                                     0.24
#
#                                                     CO2 emissions per units of GDP (kg/$1,000 of 2005 PPP $)  \
# Access to improved sanitation (% of total pop.)                                                 -0.16
# Access to improved water source (% of total pop.)                                                0.04
# CO2 emissions per capita (metric tons)                                                           0.54
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                               1.00
# CO2 emissions, total (KtCO2)                                                                     0.31
# Cereal yield (kg per hectare)                                                                   -0.26
# Child malnutrition, underweight (% of under age 5)                                               0.55
# Energy use per capita (kilograms of oil equival...                                               0.44
# Energy use per units of GDP (kg oil eq./$1,000 ...                                               0.86
# Foreign direct investment, net inflows (% of GDP)                                               -0.18
#
#                                                     CO2 emissions, total (KtCO2)  \
# Access to improved sanitation (% of total pop.)                            -0.68
# Access to improved water source (% of total pop.)                          -0.35
# CO2 emissions per capita (metric tons)                                     -0.25
# CO2 emissions per units of GDP (kg/$1,000 of 20...                          0.31
# CO2 emissions, total (KtCO2)                                                1.00
# Cereal yield (kg per hectare)                                              -0.35
# Child malnutrition, underweight (% of under age 5)                          0.77
# Energy use per capita (kilograms of oil equival...                         -0.36
# Energy use per units of GDP (kg oil eq./$1,000 ...                          0.32
# Foreign direct investment, net inflows (% of GDP)                          -0.30
#
#                                                     Cereal yield (kg per hectare)  \
# Access to improved sanitation (% of total pop.)                              0.22
# Access to improved water source (% of total pop.)                            0.08
# CO2 emissions per capita (metric tons)                                      -0.03
# CO2 emissions per units of GDP (kg/$1,000 of 20...                          -0.26
# CO2 emissions, total (KtCO2)                                                -0.35
# Cereal yield (kg per hectare)                                                1.00
# Child malnutrition, underweight (% of under age 5)                          -0.29
# Energy use per capita (kilograms of oil equival...                           0.08
# Energy use per units of GDP (kg oil eq./$1,000 ...                          -0.12
# Foreign direct investment, net inflows (% of GDP)                            0.43
#
#                                                     Child malnutrition, underweight (% of under age 5)  \
# Access to improved sanitation (% of total pop.)                                                 -0.84
# Access to improved water source (% of total pop.)                                               -0.70
# CO2 emissions per capita (metric tons)                                                          -0.49
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                               0.55
# CO2 emissions, total (KtCO2)                                                                     0.77
# Cereal yield (kg per hectare)                                                                   -0.29
# Child malnutrition, underweight (% of under age 5)                                               1.00
# Energy use per capita (kilograms of oil equival...                                              -0.56
# Energy use per units of GDP (kg oil eq./$1,000 ...                                               0.63
# Foreign direct investment, net inflows (% of GDP)                                               -0.33
#
#                                                     Energy use per capita (kilograms of oil equivalent)  \
# Access to improved sanitation (% of total pop.)                                                  0.72
# Access to improved water source (% of total pop.)                                                0.81
# CO2 emissions per capita (metric tons)                                                           0.97
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                               0.44
# CO2 emissions, total (KtCO2)                                                                    -0.36
# Cereal yield (kg per hectare)                                                                    0.08
# Child malnutrition, underweight (% of under age 5)                                              -0.56
# Energy use per capita (kilograms of oil equival...                                               1.00
# Energy use per units of GDP (kg oil eq./$1,000 ...                                               0.11
# Foreign direct investment, net inflows (% of GDP)                                                0.31
#
#                                                     Energy use per units of GDP (kg oil eq./$1,000 of 2005 PPP $)  \
# Access to improved sanitation (% of total pop.)                                                 -0.49
# Access to improved water source (% of total pop.)                                               -0.42
# CO2 emissions per capita (metric tons)                                                           0.15
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                               0.86
# CO2 emissions, total (KtCO2)                                                                     0.32
# Cereal yield (kg per hectare)                                                                   -0.12
# Child malnutrition, underweight (% of under age 5)                                               0.63
# Energy use per capita (kilograms of oil equival...                                               0.11
# Energy use per units of GDP (kg oil eq./$1,000 ...                                               1.00
# Foreign direct investment, net inflows (% of GDP)                                               -0.29
#
#                                                     Foreign direct investment, net inflows (% of GDP)  \
# Access to improved sanitation (% of total pop.)                                                  0.41
# Access to improved water source (% of total pop.)                                                0.40
# CO2 emissions per capita (metric tons)                                                           0.24
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                              -0.18
# CO2 emissions, total (KtCO2)                                                                    -0.30
# Cereal yield (kg per hectare)                                                                    0.43
# Child malnutrition, underweight (% of under age 5)                                              -0.33
# Energy use per capita (kilograms of oil equival...                                               0.31
# Energy use per units of GDP (kg oil eq./$1,000 ...                                              -0.29
# Foreign direct investment, net inflows (% of GDP)                                                1.00
#
#                                                     ...  \
# Access to improved sanitation (% of total pop.)     ...
# Access to improved water source (% of total pop.)   ...
# CO2 emissions per capita (metric tons)              ...
# CO2 emissions per units of GDP (kg/$1,000 of 20...  ...
# CO2 emissions, total (KtCO2)                        ...
# Cereal yield (kg per hectare)                       ...
# Child malnutrition, underweight (% of under age 5)  ...
# Energy use per capita (kilograms of oil equival...  ...
# Energy use per units of GDP (kg oil eq./$1,000 ...  ...
# Foreign direct investment, net inflows (% of GDP)   ...
#
#                                                     Physicians (per 1,000 people)  \
# Access to improved sanitation (% of total pop.)                              0.57
# Access to improved water source (% of total pop.)                            0.67
# CO2 emissions per capita (metric tons)                                       0.51
# CO2 emissions per units of GDP (kg/$1,000 of 20...                           0.00
# CO2 emissions, total (KtCO2)                                                -0.25
# Cereal yield (kg per hectare)                                               -0.06
# Child malnutrition, underweight (% of under age 5)                          -0.63
# Energy use per capita (kilograms of oil equival...                           0.56
# Energy use per units of GDP (kg oil eq./$1,000 ...                          -0.25
# Foreign direct investment, net inflows (% of GDP)                            0.10
#
#                                                     Population  \
# Access to improved sanitation (% of total pop.)          -0.82
# Access to improved water source (% of total pop.)        -0.55
# CO2 emissions per capita (metric tons)                   -0.46
# CO2 emissions per units of GDP (kg/$1,000 of 20...        0.24
# CO2 emissions, total (KtCO2)                              0.94
# Cereal yield (kg per hectare)                            -0.31
# Child malnutrition, underweight (% of under age 5)        0.88
# Energy use per capita (kilograms of oil equival...       -0.56
# Energy use per units of GDP (kg oil eq./$1,000 ...        0.37
# Foreign direct investment, net inflows (% of GDP)        -0.32
#
#                                                     Population growth (annual %)  \
# Access to improved sanitation (% of total pop.)                            -0.16
# Access to improved water source (% of total pop.)                          -0.40
# CO2 emissions per capita (metric tons)                                     -0.51
# CO2 emissions per units of GDP (kg/$1,000 of 20...                         -0.38
# CO2 emissions, total (KtCO2)                                                0.07
# Cereal yield (kg per hectare)                                              -0.07
# Child malnutrition, underweight (% of under age 5)                          0.34
# Energy use per capita (kilograms of oil equival...                         -0.52
# Energy use per units of GDP (kg oil eq./$1,000 ...                         -0.26
# Foreign direct investment, net inflows (% of GDP)                          -0.07
#
#                                                     Population in urban agglomerations >1million (%)  \
# Access to improved sanitation (% of total pop.)                                                 0.35
# Access to improved water source (% of total pop.)                                               0.22
# CO2 emissions per capita (metric tons)                                                         -0.31
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                             -0.74
# CO2 emissions, total (KtCO2)                                                                   -0.28
# Cereal yield (kg per hectare)                                                                   0.21
# Child malnutrition, underweight (% of under age 5)                                             -0.63
# Energy use per capita (kilograms of oil equival...                                             -0.22
# Energy use per units of GDP (kg oil eq./$1,000 ...                                             -0.75
# Foreign direct investment, net inflows (% of GDP)                                               0.10
#
#                                                     Population living below $1.25 a day (% of total)  \
# Access to improved sanitation (% of total pop.)                                                -0.94
# Access to improved water source (% of total pop.)                                              -0.87
# CO2 emissions per capita (metric tons)                                                         -0.67
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                              0.08
# CO2 emissions, total (KtCO2)                                                                    0.63
# Cereal yield (kg per hectare)                                                                  -0.10
# Child malnutrition, underweight (% of under age 5)                                              0.85
# Energy use per capita (kilograms of oil equival...                                             -0.74
# Energy use per units of GDP (kg oil eq./$1,000 ...                                              0.43
# Foreign direct investment, net inflows (% of GDP)                                              -0.39
#
#                                                     Primary completion rate, total (% of relevant age group)  \
# Access to improved sanitation (% of total pop.)                                                  0.50
# Access to improved water source (% of total pop.)                                                0.41
# CO2 emissions per capita (metric tons)                                                           0.32
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                              -0.21
# CO2 emissions, total (KtCO2)                                                                    -0.41
# Cereal yield (kg per hectare)                                                                    0.46
# Child malnutrition, underweight (% of under age 5)                                              -0.54
# Energy use per capita (kilograms of oil equival...                                               0.41
# Energy use per units of GDP (kg oil eq./$1,000 ...                                              -0.24
# Foreign direct investment, net inflows (% of GDP)                                                0.30
#
#                                                     Ratio of girls to boys in primary & secondary school (%)  \
# Access to improved sanitation (% of total pop.)                                                  0.54
# Access to improved water source (% of total pop.)                                                0.51
# CO2 emissions per capita (metric tons)                                                           0.41
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                              -0.09
# CO2 emissions, total (KtCO2)                                                                    -0.51
# Cereal yield (kg per hectare)                                                                    0.47
# Child malnutrition, underweight (% of under age 5)                                              -0.62
# Energy use per capita (kilograms of oil equival...                                               0.52
# Energy use per units of GDP (kg oil eq./$1,000 ...                                              -0.18
# Foreign direct investment, net inflows (% of GDP)                                                0.44
#
#                                                     Under-five mortality rate (per 1,000)  \
# Access to improved sanitation (% of total pop.)                                     -0.87
# Access to improved water source (% of total pop.)                                   -0.85
# CO2 emissions per capita (metric tons)                                              -0.65
# CO2 emissions per units of GDP (kg/$1,000 of 20...                                   0.11
# CO2 emissions, total (KtCO2)                                                         0.60
# Cereal yield (kg per hectare)                                                       -0.41
# Child malnutrition, underweight (% of under age 5)                                   0.79
# Energy use per capita (kilograms of oil equival...                                  -0.73
# Energy use per units of GDP (kg oil eq./$1,000 ...                                   0.37
# Foreign direct investment, net inflows (% of GDP)                                   -0.55
#
#                                                     Urban population  \
# Access to improved sanitation (% of total pop.)                -0.81
# Access to improved water source (% of total pop.)              -0.56
# CO2 emissions per capita (metric tons)                         -0.49
# CO2 emissions per units of GDP (kg/$1,000 of 20...              0.17
# CO2 emissions, total (KtCO2)                                    0.96
# Cereal yield (kg per hectare)                                  -0.29
# Child malnutrition, underweight (% of under age 5)              0.84
# Energy use per capita (kilograms of oil equival...             -0.58
# Energy use per units of GDP (kg oil eq./$1,000 ...              0.31
# Foreign direct investment, net inflows (% of GDP)              -0.35
#
#                                                     Urban population growth (annual %)
# Access to improved sanitation (% of total pop.)                                  -0.34
# Access to improved water source (% of total pop.)                                -0.62
# CO2 emissions per capita (metric tons)                                           -0.50
# CO2 emissions per units of GDP (kg/$1,000 of 20...                               -0.20
# CO2 emissions, total (KtCO2)                                                      0.06
# Cereal yield (kg per hectare)                                                     0.06
# Child malnutrition, underweight (% of under age 5)                                0.50
# Energy use per capita (kilograms of oil equival...                               -0.50
# Energy use per units of GDP (kg oil eq./$1,000 ...                                0.07
# Foreign direct investment, net inflows (% of GDP)                                -0.15
#
# [10 rows x 29 columns]

# %%
# Compute correlation matrix for numeric columns
corr = df_imputed[numeric_cols].corr(numeric_only=True)

# Filter to only show correlations > 0.5 (excluding self-correlations)
strong_corr = (
    corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))  # keep upper triangle
    .stack()  # convert to long format
    .reset_index()
    .rename(columns={0: "Correlation", "level_0": "Variable 1", "level_1": "Variable 2"})
)

# Keep only those above threshold
strong_corr = strong_corr[strong_corr["Correlation"].abs() > 0.5].sort_values("Correlation", ascending=False)
strong_corr
# Out:
#                                             Variable 1  \
# 376                                         Population
# 59              CO2 emissions per capita (metric tons)
# 128                       CO2 emissions, total (KtCO2)
# 121                       CO2 emissions, total (KtCO2)
# 0      Access to improved sanitation (% of total pop.)
# ..                                                 ...
# 5      Access to improved sanitation (% of total pop.)
# 52   Access to improved water source (% of total pop.)
# 25     Access to improved sanitation (% of total pop.)
# 49   Access to improved water source (% of total pop.)
# 22     Access to improved sanitation (% of total pop.)
#
#                                             Variable 2  Correlation
# 376                                   Urban population     0.982485
# 59   Energy use per capita (kilograms of oil equiva...     0.969832
# 128                                   Urban population     0.955227
# 121                                         Population     0.936805
# 0    Access to improved water source (% of total pop.)     0.880170
# ..                                                 ...          ...
# 5    Child malnutrition, underweight (% of under ag...    -0.843784
# 52               Under-five mortality rate (per 1,000)    -0.850005
# 25               Under-five mortality rate (per 1,000)    -0.865682
# 49    Population living below $1.25 a day (% of total)    -0.866717
# 22    Population living below $1.25 a day (% of total)    -0.943033
#
# [104 rows x 3 columns]

# %%
country_col = "Country name"
year_col = "Year"
co2_col = "CO2 emissions per capita (metric tons)"
gdp_col ="GDP ($)"

# --- Drop missing values for both CO₂ and GDP ---
plot_df = df_imputed[[country_col, year_col, co2_col, gdp_col]].dropna()

# --- Sort values for cleaner plotting ---
plot_df = plot_df.sort_values(by=[country_col, year_col])

# --- Create a figure with 2 subplots (side by side) ---
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# ======================
# Plot 1: CO₂ emissions per capita over years
# ======================
sb.lineplot(
    data=plot_df,
    x=year_col,
    y=co2_col,
    hue=country_col,
    marker="o",
    ax=axes[0]
)
axes[0].set_title("CO₂ Emissions per Capita Over the Years (by Country)")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("CO₂ Emissions (metric tons)")
axes[0].legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")

# ======================
# Plot 2: GDP per capita over years
# ======================
sb.lineplot(
    data=plot_df,
    x=year_col,
    y=gdp_col,
    hue=country_col,
    marker="s",
    ax=axes[1]
)
axes[1].set_title("GDP per Capita Over the Years (by Country)")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("GDP per Capita (US$)")
axes[1].legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")

# ======================
# Layout adjustments
# ======================
plt.suptitle("Trends of CO₂ Emissions and GDP per Capita Over Time by Country",
             fontsize=14, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_21756\2195373078.py:52: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# C:\Users\jason\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
